# %%
from tensorflow import keras
from keras.models import Model
from keras import layers
from keras.layers import Dense, Input, BatchNormalization, Activation
from keras.layers import Conv2D, SeparableConv2D, MaxPooling2D, GlobalAveragePooling2D, GlobalMaxPooling2D
#from keras.applications.imagenet_utils import _obtain_input_shape
#from keras.utils.data_utils import get_file
from sklearn.model_selection import KFold
from keras.datasets import mnist
from PIL import Image
# for creating a one hot vector for labels
#from keras.utils import np_utils
from IPython.display import display, Image
#import the models
from keras import Model
#add layers
from keras import layers
#add optimizer
from keras import optimizers
#add loss function 
from keras import losses
import random

import keras
import numpy as np
import pandas as pd 
import os
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
from tensorflow import keras
from keras.models import Model
from keras.layers import Dense, Input, BatchNormalization, Activation
from keras.layers import Conv2D, SeparableConv2D, MaxPooling2D, GlobalAveragePooling2D
from IPython.core.display import display, HTML
import sys

# Adjust notebook display width
display(HTML("<style>.container { width:90% !important; }</style>"))


img_size = 299
def Xception():

	# Determine proper input shape
	input_shape = (img_size, img_size, 3 )#_obtain_input_shape(None, default_size=299, min_size=71, data_format='channels_last', include_top=False)

	img_input = Input(shape=input_shape)

	# Block 1
	x = Conv2D(32, (3, 3), strides=(2, 2), use_bias=False)(img_input)
	x = BatchNormalization()(x)
	x = Activation('relu')(x)
	x = Conv2D(64, (3, 3), use_bias=False)(x)
	x = BatchNormalization()(x)
	x = Activation('relu')(x)

	residual = Conv2D(128, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
	residual = BatchNormalization()(residual)

	# Block 2
	x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False)(x)
	x = BatchNormalization()(x)
	x = Activation('relu')(x)
	x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False)(x)
	x = BatchNormalization()(x)

	# Block 2 Pool
	x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
	x = layers.add([x, residual])

	residual = Conv2D(256, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
	residual = BatchNormalization()(residual)

	# Block 3
	x = Activation('relu')(x)
	x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False)(x)
	x = BatchNormalization()(x)
	x = Activation('relu')(x)
	x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False)(x)
	x = BatchNormalization()(x)

	# Block 3 Pool
	x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
	x = layers.add([x, residual])

	residual = Conv2D(728, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
	residual = BatchNormalization()(residual)

	# Block 4
	x = Activation('relu')(x)
	x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False)(x)
	x = BatchNormalization()(x)
	x = Activation('relu')(x)
	x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False)(x)
	x = BatchNormalization()(x)

	x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
	x = layers.add([x, residual])

	# Block 5 - 12
	for i in range(8):
		residual = x

		x = Activation('relu')(x)
		x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False)(x)
		x = BatchNormalization()(x)
		x = Activation('relu')(x)
		x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False)(x)
		x = BatchNormalization()(x)
		x = Activation('relu')(x)
		x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False)(x)
		x = BatchNormalization()(x)

		x = layers.add([x, residual])

	residual = Conv2D(1024, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
	residual = BatchNormalization()(residual)

	# Block 13
	x = Activation('relu')(x)
	x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False)(x)
	x = BatchNormalization()(x)
	x = Activation('relu')(x)
	x = SeparableConv2D(1024, (3, 3), padding='same', use_bias=False)(x)
	x = BatchNormalization()(x)

	# Block 13 Pool
	x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
	x = layers.add([x, residual])

	# Block 14
	x = SeparableConv2D(1536, (3, 3), padding='same', use_bias=False)(x)
	x = BatchNormalization()(x)
	x = Activation('relu')(x)

	# Block 14 part 2
	x = SeparableConv2D(2048, (3, 3), padding='same', use_bias=False)(x)
	x = BatchNormalization()(x)
	x = Activation('relu')(x)

	# Fully Connected Layer
	x = GlobalAveragePooling2D()(x)
	x = Dense( 3 , activation='softmax')(x)

	inputs = img_input

	# Create model
	model = Model(inputs, x, name='xception')

	# Download and cache the Xception weights file


	return model

model = Xception()
model.compile(
    optimizer='Adam',
    loss=keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=["acc"],
)

# Print the model summary
model.summary(print_fn=lambda x: sys.stdout.write(x + '\n'))
# Out:
# <style>.container { width:90% !important; }</style>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Model: "xception"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 299, 299, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 149, 149, 32)   │            864 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...

# %%
categories = {
    "Brown_blight": 792,
    "Grey_blight": 848-2,
    "Healthy": 809,
    "Red_rust": 789-2,
}

folds = 5

fold_distribution = {}
for category, images in categories.items():
    images_per_fold = images // folds
    r = images % folds
    fold_distribution[category] = []
    for i in range(0, folds):
        if i < r:
            fold_distribution[category].append(images_per_fold + 1)
        else:
            fold_distribution[category].append(images_per_fold)

print(fold_distribution)
# Out:
# {'Brown_blight': [159, 159, 158, 158, 158], 'Grey_blight': [170, 169, 169, 169, 169], 'Healthy': [162, 162, 162, 162, 161], 'Red_rust': [158, 158, 157, 157, 157]}

# %%
sample = []
a = []

for category, images in fold_distribution.items():
    if category == "Brown_blight":
        a = images

image_path="/kaggle/input/tea-images/Tea Images/Brown_blight"
image_list = os.listdir(image_path)
random.shuffle(image_list)
fold = 0
num_image_in_fold = 0

inserted = []

for i in image_list:
    if i not in inserted:
        inserted.append(i)
    else:
        print( i+" is already inserted.")
        continue
    sample.append([i , fold, "Brown_blight"])
    num_image_in_fold = num_image_in_fold + 1
    if num_image_in_fold == a[fold]:
        fold = fold + 1
        num_image_in_fold = 0
    

print(len(sample))
# Out:
# 792

# %%
a = []

for category, images in fold_distribution.items():
    if category == "Grey_blight":
        a = images

image_path="/kaggle/input/tea-images/Tea Images/Grey_blight"
image_list = os.listdir(image_path)
random.shuffle(image_list)
fold = 0
num_image_in_fold = 0

inserted = []

for i in range(0, len(image_list)):
    if "Untitled" in image_list[i]:
        continue
    if image_list[i] not in inserted:
        inserted.append(image_list[i])
    else:
        print( image_list[i]+" is already inserted.")
        continue
    sample.append([image_list[i] , fold, "Grey_blight"])
    num_image_in_fold = num_image_in_fold + 1
    if num_image_in_fold == a[fold]:
        fold = fold + 1
        num_image_in_fold = 0
    

print(len(sample))
# Out:
# 1638

# %%
a = []

for category, images in fold_distribution.items():
    if category == "Healthy":
        a = images

image_path="/kaggle/input/tea-images/Tea Images/Healthy"
image_list = os.listdir(image_path)
random.shuffle(image_list)
fold = 0
num_image_in_fold = 0

inserted = []

for i in range(0, len(image_list)):
    if "Untitled" in image_list[i]:
        continue
    if image_list[i] not in inserted:
        inserted.append(image_list[i])
    else:
        print( image_list[i]+" is already inserted.")
        continue
    sample.append([image_list[i] , fold, "Healthy"])
    num_image_in_fold = num_image_in_fold + 1
    if num_image_in_fold == a[fold]:
        fold = fold + 1
        num_image_in_fold = 0
    

print(len(sample))
# Out:
# 2447

# %%
a = []

for category, images in fold_distribution.items():
    if category == "Red_rust":
        a = images

image_path="/kaggle/input/tea-images/Tea Images/Red_rust"
image_list = os.listdir(image_path)
random.shuffle(image_list)
fold = 0
num_image_in_fold = 0

inserted = []

for i in range(0, len(image_list)):
    if "Untitled" in image_list[i]:
        continue
    if image_list[i] not in inserted:
        inserted.append(image_list[i])
    else:
        print( image_list[i]+" is already inserted.")
        continue
    sample.append([image_list[i] , fold, "Red_rust"])
    num_image_in_fold = num_image_in_fold + 1
    if num_image_in_fold == a[fold]:
        fold = fold + 1
        num_image_in_fold = 0
    

print(len(sample))
# Out:
# 3234

# %%
sample = np.array(sample)
sample = pd.DataFrame(sample, columns = ["image_name", "fold", "category"])

print(len(sample))

columns = sample.columns
columns = list(columns)
print(columns)
# Out:
# 3234
# ['image_name', 'fold', 'category']

# %%
cat = sample.groupby("category")

for category, images in cat:
    print(category)
    print(len(images))
    image_names = images.groupby("fold")
    for i,j in image_names:
        print(i," ",len(j))

print()
# Out:
# Brown_blight
# 792
# 0   159
# 1   159
# 2   158
# 3   158
# 4   158
# Grey_blight
# 846
# 0   170
# 1   169
# 2   169
# 3   169
# 4   169
# Healthy
# 809
# 0   162
# 1   162
# 2   162
# 3   162
# 4   161
# Red_rust
# 787
# 0   158
# 1   158
# 2   157
# 3   157
# 4   157

# %%
image_name = sample["image_name"]
image_name = list(image_name)
has_duplicates = len(image_name) != len(set(image_name))
print(has_duplicates)
# Out:
# False

# %%
print(len(sample))
print(sample)

sample.to_csv('/kaggle/working/splited_into_5_fold.csv', index=False) 
print(os.listdir('/kaggle/working'))

from IPython.display import FileLink

# Generate a download link
"""
file_path = '/kaggle/working/splited_into_5_fold.csv'
FileLink(file_path)
"""
# Out:
# 3234
#                  image_name fold      category
# 0      Training_img_280.jpg    0  Brown_blight
# 1      Training_img_662.jpg    0  Brown_blight
# 2      Training_img_651.jpg    0  Brown_blight
# 3      Training_img_809.jpg    0  Brown_blight
# 4      Training_img_546.jpg    0  Brown_blight
# ...                     ...  ...           ...
# 3229  Training_img_2989.jpg    4      Red_rust
# 3230  Training_img_2880.jpg    4      Red_rust
# 3231  Training_img_2693.jpg    4      Red_rust
# 3232  Training_img_2997.jpg    4      Red_rust
# 3233  Training_img_2993.jpg    4      Red_rust
#
# [3234 rows x 3 columns]
# ['.virtual_documents', 'splited_into_5_fold.csv']
# "\nfile_path = '/kaggle/working/splited_into_5_fold.csv'\nFileLink(file_path)\n"

# %%
print("Hello world.")
# Out:
# Hello world.
